# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from skimage.filters import threshold_otsu
from skimage.io import imread
from skimage.color import rgb2gray
from skimage.measure import label, regionprops
import json
import os
# import uuid
from PIL import Image
import random
import Augmentor

# %%
p = Augmentor.Pipeline("training_data\images")
p.rotate90(probability=0.7)
p.process()
# Out:
# Initialised with 1328 image(s) found.
# Output directory set to training_data\images\output.
# Processing <PIL.Image.Image image mode=RGB size=1200x1600 at 0x1C600B4C828>: 100%|█| 1328/1328 [01:12<00:00, 18.38 Samples/s]

# %%
img = imread('training_data/Falciparum/img/1704282807-0019-R_T.tif',plugin="pil")
plt.imshow(img)

# %%
mask2 = np.zeros((1944, 2592, 3))
mask2[:,:,0] = mask
mask2[:,:,1] = mask
mask2[:,:,2] = mask
tmp = img * mask2

# %%
print(np.shape(tmp))
# Out:
# (1944, 2592, 3)

# %%
tmp = tmp.astype(int)
plt.imshow(tmp)
